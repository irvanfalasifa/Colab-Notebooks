# %%
import pandas as pd
import io

df = pd.read_csv('https://raw.githubusercontent.com/curran/data/gh-pages/Rdatasets/csv/car/Florida.csv')
print(df)
# Out:
#     Unnamed: 0   GORE    BUSH  ...  MOOREHEAD  PHILLIPS   Total
# 0      ALACHUA  47300   34062  ...         21        20   86242
# 1        BAKER   2392    5610  ...          3         3    8154
# 2          BAY  18850   38637  ...         37        18   58815
# 3     BRADFORD   3072    5413  ...          3         2    8669
# 4      BREVARD  97318  115185  ...         76        72  218395
# ..         ...    ...     ...  ...        ...       ...     ...
# 62       UNION   1399    2326  ...          0         0    3794
# 63     VOLUSIA  97063   82214  ...         59      2927  198230
# 64     WAKULLA   3835    4511  ...          6         0    8583
# 65      WALTON   5637   12176  ...         18         7   18307
# 66  WASHINGTON   2796    4983  ...          5         9    8026
#
# [67 rows x 12 columns]
