# %%
pip install pillow
# Out:
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (7.1.2)

# %%
pip install image
# Out:
# Collecting image
#   Downloading image-1.5.33.tar.gz (15 kB)
# Requirement already satisfied: pillow in /usr/local/lib/python3.7/dist-packages (from image) (7.1.2)
# Collecting django
#   Downloading Django-3.2.13-py3-none-any.whl (7.9 MB)
#      |████████████████████████████████| 7.9 MB 4.8 MB/s
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from image) (1.15.0)
# Requirement already satisfied: sqlparse>=0.2.2 in /usr/local/lib/python3.7/dist-packages (from django->image) (0.4.2)
# Requirement already satisfied: pytz in /usr/local/lib/python3.7/dist-packages (from django->image) (2022.1)
# Collecting asgiref<4,>=3.3.2
#   Downloading asgiref-3.5.0-py3-none-any.whl (22 kB)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from asgiref<4,>=3.3.2->django->image) (4.2.0)
# Building wheels for collected packages: image
#   Building wheel for image (setup.py) ... done
#   Created wheel for image: filename=image-1.5.33-py2.py3-none-any.whl size=19496 sha256=82967b5de2892adfa6b38eec20c5f40a8099c1a408dacbae6ae97564b0b9fff6
#   Stored in directory: /root/.cache/pip/wheels/56/88/e6/897194cfe8c08a8b9afd881d3bf53d102e13fa39607d721383
# Successfully built image
# Installing collected packages: asgiref, django, image
# Successfully installed asgiref-3.5.0 django-3.2.13 image-1.5.33

# %%
import PIL
from PIL import Image
from tkinter.filedialog import *

path = askopenfilename()
img = PIL.image.open(path)
Height, Width = img.size

img = img.resize((Height, Width), PIL.image.ANTIALIAS)
save_path = asksaveasfilename()

img.save(save_path+"_compressed.PNG")
# Out:
# ---------------------------------------------------------------------------
# TclError                                  Traceback (most recent call last)
# <ipython-input-5-3635d8c54818> in <module>()
#       3 from tkinter.filedialog import *
#       4
# ----> 5 path = askopenfilename()
#       6 img = PIL.image.open(path)
#       7 Height, Width = img.size
#
# /usr/lib/python3.7/tkinter/filedialog.py in askopenfilename(**options)
#     373     "Ask for a filename to open"
#     374
# --> 375     return Open(**options).show()
#     376
#     377 def asksaveasfilename(**options):
#
# /usr/lib/python3.7/tkinter/commondialog.py in show(self, **options)
#      37         # we need a dummy widget to properly process the options
#      38         # (at least as long as we use Tkinter 1.63)
# ---> 39         w = Frame(self.master)
#      40
#      41         try:
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, master, cnf, **kw)
#    2742             extra = ('-class', cnf['class'])
#    2743             del cnf['class']
# -> 2744         Widget.__init__(self, master, 'frame', cnf, {}, extra)
#    2745
#    2746 class Label(Widget):
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, master, widgetName, cnf, kw, extra)
#    2290             cnf = _cnfmerge((cnf, kw))
#    2291         self.widgetName = widgetName
# -> 2292         BaseWidget._setup(self, master, cnf)
#    2293         if self._tclCommands is None:
#    2294             self._tclCommands = []
#
# /usr/lib/python3.7/tkinter/__init__.py in _setup(self, master, cnf)
#    2257             if not master:
#    2258                 if not _default_root:
# -> 2259                     _default_root = Tk()
#    2260                 master = _default_root
#    2261         self.master = master
#
# /usr/lib/python3.7/tkinter/__init__.py in __init__(self, screenName, baseName, className, useTk, sync, use)
#    2021                 baseName = baseName + ext
#    2022         interactive = 0
# -> 2023         self.tk = _tkinter.create(screenName, baseName, className, interactive, wantobjects, useTk, sync, use)
#    2024         if useTk:
#    2025             self._loadtk()
#
# TclError: no display name and no $DISPLAY environment variable
